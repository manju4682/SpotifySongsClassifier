# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Songs_details.csv')

# %%
df.head(5)
# Out:
#                        id                              name  duration  \
# 0  4cFwhwH5ydnHgB0Tv3lZsm  O Saki Saki (From "Batla House")    191089
# 1  4tjLYTXFqZhkUDga4bQ0yl  Dilbar (From "Satyameva Jayate")    184432
# 2  1feANd8EfcDP5UqSvbheM3    Bekhayali (From "Kabir Singh")    371790
# 3  352wEkChkiClswqwDoM0nj    Coca Cola (From "Luka Chuppi")    179225
# 4  5x72Q1SyiDHJ4IF2mRzfkg  Gali Gali (From "Kgf Chapter 1")    174711
#
#      artist_name  is_explicit  time_signature  danceability  energy  key  \
# 0    Neha Kakkar        False               4         0.737   0.961   10
# 1    Neha Kakkar        False               4         0.725   0.912    9
# 2  Sachet Tandon        False               3         0.308   0.585    9
# 3    Tony Kakkar        False               4         0.722   0.867    0
# 4    Neha Kakkar        False               4         0.789   0.950    5
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -0.155     0       0.0747         0.163          0.000000    0.3610
# 1    -3.665     0       0.0851         0.155          0.000077    0.1070
# 2    -5.180     0       0.0428         0.450          0.000000    0.3190
# 3    -3.652     0       0.0904         0.121          0.005200    0.1230
# 4    -3.604     0       0.0759         0.191          0.000014    0.0969
#
#    valence    tempo  popularity
# 0    0.567  108.014          64
# 1    0.674  104.054          56
# 2    0.345  171.843          63
# 3    0.893  102.009          59
# 4    0.746  126.013          55

# %%
df.corr()
# Out:
#                   duration  is_explicit  time_signature  danceability  \
# duration          1.000000    -0.057120       -0.004654     -0.165690
# is_explicit      -0.057120     1.000000        0.037366      0.118886
# time_signature   -0.004654     0.037366        1.000000      0.174613
# danceability     -0.165690     0.118886        0.174613      1.000000
# energy            0.085666     0.076510        0.190170      0.164066
# key              -0.009148     0.003022        0.011528      0.026638
# loudness          0.026607     0.117772        0.183645      0.237186
# mode             -0.001524    -0.015976       -0.022361     -0.063057
# speechiness      -0.058903     0.269093        0.052342      0.170228
# acousticness     -0.075587    -0.126376       -0.183369     -0.196333
# instrumentalness -0.053743    -0.102028       -0.104944     -0.169860
# liveness          0.057906     0.044186        0.034668     -0.057741
# valence          -0.070604    -0.010681        0.132844      0.483947
# tempo             0.021551     0.031782       -0.031899     -0.121345
# popularity       -0.110711     0.100382        0.026718      0.067204
#
#                     energy       key  loudness      mode  speechiness  \
# duration          0.085666 -0.009148  0.026607 -0.001524    -0.058903
# is_explicit       0.076510  0.003022  0.117772 -0.015976     0.269093
# time_signature    0.190170  0.011528  0.183645 -0.022361     0.052342
# danceability      0.164066  0.026638  0.237186 -0.063057     0.170228
# energy            1.000000  0.023592  0.794586 -0.035301     0.154157
# key               0.023592  1.000000  0.016334 -0.123747     0.022992
# loudness          0.794586  0.016334  1.000000 -0.013609     0.111145
# mode             -0.035301 -0.123747 -0.013609  1.000000    -0.075018
# speechiness       0.154157  0.022992  0.111145 -0.075018     1.000000
# acousticness     -0.758901 -0.022310 -0.640141  0.032731    -0.121078
# instrumentalness -0.388474 -0.003193 -0.557231 -0.063714    -0.050425
# liveness          0.202895 -0.007618  0.139153 -0.011996     0.094343
# valence           0.390986  0.037262  0.298841  0.007088     0.120446
# tempo             0.182463  0.004362  0.141814  0.012759     0.076296
# popularity        0.027342  0.004366  0.036047  0.013674     0.047659
#
#                   acousticness  instrumentalness  liveness   valence  \
# duration             -0.075587         -0.053743  0.057906 -0.070604
# is_explicit          -0.126376         -0.102028  0.044186 -0.010681
# time_signature       -0.183369         -0.104944  0.034668  0.132844
# danceability         -0.196333         -0.169860 -0.057741  0.483947
# energy               -0.758901         -0.388474  0.202895  0.390986
# key                  -0.022310         -0.003193 -0.007618  0.037262
# loudness             -0.640141         -0.557231  0.139153  0.298841
# mode                  0.032731         -0.063714 -0.011996  0.007088
# speechiness          -0.121078         -0.050425  0.094343  0.120446
# acousticness          1.000000          0.318568 -0.148047 -0.253701
# instrumentalness      0.318568          1.000000 -0.072869 -0.254416
# liveness             -0.148047         -0.072869  1.000000  0.061981
# valence              -0.253701         -0.254416  0.061981  1.000000
# tempo                -0.163357         -0.090999  0.038963  0.062059
# popularity           -0.033088         -0.022866 -0.024045  0.037193
#
#                      tempo  popularity
# duration          0.021551   -0.110711
# is_explicit       0.031782    0.100382
# time_signature   -0.031899    0.026718
# danceability     -0.121345    0.067204
# energy            0.182463    0.027342
# key               0.004362    0.004366
# loudness          0.141814    0.036047
# mode              0.012759    0.013674
# speechiness       0.076296    0.047659
# acousticness     -0.163357   -0.033088
# instrumentalness -0.090999   -0.022866
# liveness          0.038963   -0.024045
# valence           0.062059    0.037193
# tempo             1.000000   -0.004088
# popularity       -0.004088    1.000000

# %%
df.sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-9baf0daa5fc6> in <module>
# ----> 1 df.sort_values()
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
df.info

# %%
df.columns

# %%
y = df.popularity

# %%
features = ['duration','is_explicit',]

# %%
X = df[features]

# %%
print(X)

# %%
print(X)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
model = DecisionTreeRegressor()
# Fit model
model.fit(train_X, train_y)
# Out:
# DecisionTreeRegressor()

# %%
val_predictions = model.predict(val_X)

# %%
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 27.033974233356947

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 100)
regressor.fit(train_X, train_y)
# Out:
# RandomForestRegressor()

# %%
predictions = regressor.predict(val_X)

# %%
print(mean_absolute_error(val_y,predictions))
# Out:
# 24.296148903517064

# %%
artists = df['artist_name'].value_counts().index[0:25]

# %%
artists

# %%
for artist in artists:
    print(artist)
